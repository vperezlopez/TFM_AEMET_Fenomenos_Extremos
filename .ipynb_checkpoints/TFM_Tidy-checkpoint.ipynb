# %%
import pandas as pd
import numpy as np

from loader import cargar_dataset

# %% [markdown]
# ### Carga del Dataset

# %%
df = cargar_dataset('Valores_Climatologicos_1970_2024_Limpios.csv')

# %%
display(df)
# Out:
#              fecha indicativo                    nombre   provincia  altitud  \
# 0       1970-01-01      C249I  FUERTEVENTURA AEROPUERTO  LAS PALMAS       25
# 1       1970-01-01      1679A         MONFORTE DE LEMOS        LUGO      291
# 2       1970-01-01       2462     PUERTO DE NAVACERRADA      MADRID     1893
# 3       1970-01-01      1212E       ASTURIAS AEROPUERTO    ASTURIAS      127
# 4       1970-01-01      0016A           REUS AEROPUERTO   TARRAGONA       71
# ...            ...        ...                       ...         ...      ...
# 7424496 2024-12-31      9562X                   MORELLA   CASTELLON      990
# 7424497 2024-12-31      1002Y           BAZTAN, IRURITA     NAVARRA      183
# 7424498 2024-12-31      3254Y                      MORA      TOLEDO      717
# 7424499 2024-12-31      0194D   CORBERA, PUIG D'AGULLES   BARCELONA      647
# 7424500 2024-12-31      4093Y            OSA DE LA VEGA      CUENCA      763
#
# ...

# %%
df.dtypes
# Out:
# fecha         datetime64[ns]
# indicativo    string[python]
# nombre        string[python]
# provincia     string[python]
# altitud                Int64
# tmed                 Float64
# prec                 Float64
# tmin                 Float64
# tmax                 Float64
# velmedia             Float64
# sol                  Float64
# presMax              Float64
# presMin              Float64
# hrMedia              Float64
# dir                  Float64
# racha                Float64
# hrMax                Float64
# hrMin                Float64
# lon                  Float64
# lat                  Float64
# dtype: object

# %% [markdown]
# ### Reestructuración en formato tidy data

# %%
# Columna con las fechas
COL_FECHA = 'fecha'

# Columnas con la ubicación de cada medición
cols_localizacion = [
    'nombre',
    'provincia',
]
# Columnas con las variables que usaremos en la visualización
cols_variables = [
    'tmax',
    'tmed',
    'tmin',
    'sol',
    'racha',
    'velmedia',
    'hrMax',
    'hrMedia',
    'hrMin',
    'prec'
]

# Nombres de las columnas a añadir
COL_VAR = 'variable'
COL_VAL = 'valor'

# %%
df_tidy = df.copy(deep = True)

# %%
# Despivotamos las columnas con las variables, convirtiéndolas en pares variable - valor
df_tidy = df_tidy.melt(
    id_vars = [COL_FECHA] + cols_localizacion,
    value_vars = cols_variables,
    var_name = COL_VAR,
    value_name = COL_VAL
)

# %%
# Limpiamos todas aquellas que no tengan valor
df_tidy = df_tidy.dropna(subset=[COL_VAL])

# %%
display(df_tidy.sample(20))
# Out:
#               fecha                       nombre               provincia  \
# 51667894 2024-01-23          PANTICOSA, PETROSOS                  HUESCA
# 46965048 2007-04-24                  CAMPDEVANOL                  GIRONA
# 40341359 2011-03-30     LOS TOJOS, BÁRCENA MAYOR               CANTABRIA
# 22860472 1983-04-26        SAN JAVIER AEROPUERTO                  MURCIA
# 14028402 2022-06-12                      AMURRIO             ARABA/ALAVA
# 55314022 2011-09-12  BOADILLA FUENTE SAN ESTEBAN               SALAMANCA
# 64110275 2016-05-23                      ARCHENA                  MURCIA
# 33703144 2014-01-17         SAN ANDRÉS, VALVERDE  SANTA CRUZ DE TENERIFE
# 34633014 2017-02-10                      JALANCE                VALENCIA
# 64961040 2019-02-21      SAN PABLO DE LOS MONTES                  TOLEDO
# 34925269 2018-01-20                COLL DE NARGÓ                  LLEIDA
# 66665746 2024-07-09       VÉLEZ BLANCO - TOPARES                 ALMERIA
# ...

# %%
df_tidy.to_csv('Valores_Climatologicos_1970_2024_Tidy_Lite.csv', sep = ';', index = False)
