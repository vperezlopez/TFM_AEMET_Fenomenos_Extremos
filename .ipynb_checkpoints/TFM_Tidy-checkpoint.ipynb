# %%
import pandas as pd
import numpy as np

import constantes as const
from loader import cargar_dataset

# %% [markdown]
# ### Carga del Dataset

# %%
df = cargar_dataset(const.PATH_DF_PROCESADO)

# %%
display(df)
# Out:
#              fecha indicativo                    nombre   provincia  altitud  \
# 0       1970-01-01      C249I  FUERTEVENTURA AEROPUERTO  LAS PALMAS       25
# 1       1970-01-01      1679A         MONFORTE DE LEMOS        LUGO      291
# 2       1970-01-01       2462     PUERTO DE NAVACERRADA      MADRID     1893
# 3       1970-01-01      1212E       ASTURIAS AEROPUERTO    ASTURIAS      127
# 4       1970-01-01      0016A           REUS AEROPUERTO   TARRAGONA       71
# ...            ...        ...                       ...         ...      ...
# 7424496 2024-12-31      9562X                   MORELLA   CASTELLON      990
# 7424497 2024-12-31      1002Y           BAZTAN, IRURITA     NAVARRA      183
# 7424498 2024-12-31      3254Y                      MORA      TOLEDO      717
# 7424499 2024-12-31      0194D   CORBERA, PUIG D'AGULLES   BARCELONA      647
# 7424500 2024-12-31      4093Y            OSA DE LA VEGA      CUENCA      763
#
# ...

# %%
df.dtypes
# Out:
# fecha         datetime64[ns]
# indicativo    string[python]
# nombre        string[python]
# provincia     string[python]
# altitud                Int64
# tmed                 Float64
# prec                 Float64
# tmin                 Float64
# tmax                 Float64
# velmedia             Float64
# sol                  Float64
# hrMedia              Float64
# racha                Float64
# hrMax                Float64
# hrMin                Float64
# lon                  Float64
# lat                  Float64
# dtype: object

# %% [markdown]
# ### Reestructuración en formato tidy data

# %%
df_tidy = df.copy(deep = True)

# %%
# Despivotamos las columnas con las variables, convirtiéndolas en pares variable - valor
df_tidy = df_tidy.melt(
    id_vars = [const.COL_FECHA] + const.COLS_LOCALIZACION,
    value_vars = const.COLS_VARIABLES,
    var_name = const.COL_VAR,
    value_name = const.COL_VAL
)

# %%
# Limpiamos todas aquellas que no tengan valor
df_tidy = df_tidy.dropna(subset=[const.COL_VAL])

# %%
display(df_tidy.sample(20))
# Out:
#               fecha                 nombre               provincia  variable  \
# 40650605 2012-05-17                  ARICO  SANTA CRUZ DE TENERIFE     racha
# 3618695  2012-09-12                 ESPIEL                 CORDOBA      tmax
# 26682850 2015-05-24   STA.CRUZ DE TENERIFE  SANTA CRUZ DE TENERIFE       sol
# 42214639 2017-08-14                  FRAGA                  HUESCA     racha
# 4756094  2016-07-12              BENAHAVÍS                  MALAGA      tmax
# 42064510 2017-02-18    VALVERDE DEL FRESNO                 CACERES     racha
# 4855452  2016-11-07                SEGOVIA                 SEGOVIA      tmax
# 20035115 2017-12-02                SEGOVIA                 SEGOVIA      tmin
# 34942374 2018-02-09              CAÑAVERAL                 CACERES  velmedia
# 29868826 1974-04-24    ÁVILA, AYUNTAMIENTO                   AVILA  velmedia
# 7483104  1971-07-30  VALLE DE HECHO, HECHO                  HUESCA      tmed
# ...

# %%
df_tidy.to_csv(const.PATH_DF_TIDY, sep = ';', index = False)
