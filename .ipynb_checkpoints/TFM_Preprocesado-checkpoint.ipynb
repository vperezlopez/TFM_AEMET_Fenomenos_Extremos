# %%
import pandas as pd
import numpy as np

import constantes as const
from loader import cargar_dataset

# %%
df = cargar_dataset(url = const.PATH_DF_BRUTO, variables_brutas = True)

# %%
display(df.sample(20))
# Out:
#              fecha indicativo                         nombre  \
# 1230219 1994-08-11      2630X           PUERTO DE SAN ISIDRO
# 470627  1980-10-11      9263D           PAMPLONA, AEROPUERTO
# 6332467 2021-08-01      4395X      VILLAFRANCA DE LOS BARROS
# 1820122 2002-03-15       9207          VALLE DE HECHO, HECHO
# 4246665 2014-11-06      8503Y                    TORREBLANCA
# 1029390 1991-08-05       2465                        SEGOVIA
# 4546397 2015-11-01      1038X                       AZPEITIA
# 1800478 2001-12-26       B278  PALMA DE MALLORCA, AEROPUERTO
# 5782261 2019-10-30       4260           PERALEDA DEL ZAUCEJO
# 3172337 2011-01-22      3536X                          HOYOS
# 547692  1982-06-21      0252D                  ARENYS DE MAR
# 6241735 2021-04-18      1078C                      BALMASEDA
# 2903758 2010-01-08      B334X                      LLUCMAJOR
# 1268431 1995-02-23       7031          SAN JAVIER AEROPUERTO
# ...

# %% [markdown]
# ### Preprocesado del Dataframe

# %%
df_prep = df.copy(deep = True)

# %%
# Eliminamos las filas de precipitación acumulada, y cambiamos los valores 'Ip' por 0 (Ip = inferior a 0,1 mm)
df_prep = df_prep[df_prep[const.COL_PREC] != 'Acum']
df_prep[const.COL_PREC] = df_prep[const.COL_PREC].replace('Ip', 0)

# %%
# Reemplazamos las comas por puntos para poder cargar los números como decimales (floats)
df_prep[const.COLS_VARIABLES] = df_prep[const.COLS_VARIABLES].replace(',', '.', regex=True).apply(pd.to_numeric, errors = 'raise')

# %%
df_prep.dtypes
# Out:
# fecha         datetime64[ns]
# indicativo    string[python]
# nombre        string[python]
# provincia     string[python]
# altitud                Int64
# tmed                 float64
# prec                 float64
# tmin                 float64
# tmax                 float64
# velmedia             float64
# sol                  float64
# presMax              float64
# presMin              float64
# hrMedia              float64
# dir                  float64
# racha                float64
# hrMax                float64
# hrMin                float64
# lon                  Float64
# lat                  Float64
# dtype: object

# %%
# Corregimos inconsistencias en nombres de provincias
df_prep.loc[df_prep[const.COL_PROVINCIA] == 'BALEARES', const.COL_PROVINCIA] = 'ILLES BALEARS'
df_prep.loc[df_prep[const.COL_PROVINCIA] == 'STA. CRUZ DE TENERIFE', const.COL_PROVINCIA] = 'SANTA CRUZ DE TENERIFE'

# %%
# Borramos dos datos de una medición anómala
df_prep.loc[
    (df_prep[const.COL_INDICATIVO] == '6084X') &
    (df_prep[const.COL_TMIN] == 50.0) &
    (df_prep[const.COL_TMAX] == -50.0),
    [const.COL_TMIN, const.COL_TMAX]
] = np.nan

# %%
# Dejamos a NaN aquellos valores desconocidos (88: 'Desconocida') o múltiples (99: 'Varias), según el fichero de metadatos
df[const.COL_DIR] = df[const.COL_DIR].replace([99, 88], np.nan)

# %%
df_prep.sample(20)
# Out:
#              fecha indicativo                   nombre  \
# 6889724 2023-05-02      9546B                    HIJAR
# 1004662 1991-03-09       0341            TONA (ESCOLA)
# 4439276 2015-06-25      4263X              VALSEQUILLO
# 1673335 2000-06-28      6325O       ALMERÍA AEROPUERTO
# 1218569 1994-06-13      0201D  BARCELONA, PORT OLÍMPIC
# 248588  1976-01-12       8175      ALBACETE BASE AÉREA
# 1099415 1992-09-14      3260B                   TOLEDO
# 389955  1979-01-16       3129        MADRID AEROPUERTO
# 148738  1973-10-22       3200                   GETAFE
# 4583545 2015-12-16      1060X                  AMURRIO
# 4896890 2016-12-23       B954        IBIZA, AEROPUERTO
# 2617665 2008-09-14      2946X        SAELICES EL CHICO
# 3046564 2010-07-30      6057X                  MANILVA
# 2547217 2008-03-31      6032B                    RONDA
# 4634496 2016-02-15      8050X             JÁVEA/ XÀBIA
# 5593332 2019-03-23      1435C                     NOIA
# ...

# %%
display(df_prep.describe().style.format({col: "{:.2f}" for col in df_prep.columns if col != const.COL_FECHA})) # Formateamos todo con 2 decimales excepto la fecha
# Out:
# <style type="text/css">
# </style>
# <table id="T_6ed54">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6ed54_level0_col0" class="col_heading level0 col0" >fecha</th>
#       <th id="T_6ed54_level0_col1" class="col_heading level0 col1" >altitud</th>
#       <th id="T_6ed54_level0_col2" class="col_heading level0 col2" >tmed</th>
#       <th id="T_6ed54_level0_col3" class="col_heading level0 col3" >prec</th>
#       <th id="T_6ed54_level0_col4" class="col_heading level0 col4" >tmin</th>
#       <th id="T_6ed54_level0_col5" class="col_heading level0 col5" >tmax</th>
#       <th id="T_6ed54_level0_col6" class="col_heading level0 col6" >velmedia</th>
#       <th id="T_6ed54_level0_col7" class="col_heading level0 col7" >sol</th>
#       <th id="T_6ed54_level0_col8" class="col_heading level0 col8" >presMax</th>
#       <th id="T_6ed54_level0_col9" class="col_heading level0 col9" >presMin</th>
# ...

# %%
df_prep.to_csv(const.PATH_DF_PROCESADO, sep = ';', index = False)
