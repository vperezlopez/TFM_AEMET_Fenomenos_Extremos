# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.statespace.varmax import VARMAX

from sklearn.metrics import mean_squared_error, mean_absolute_error

import constantes as const
from loader import cargar_dataset

# %%
columnas_descartables = [
    'indicativo',
    'nombre',
    'dir'
]

# %%
df = cargar_dataset('Valores_Climatologicos_1970_2024_Limpios.csv').drop(columns = columnas_descartables)

# %%
display(df.sample(20))
# Out:
#              fecha               provincia  altitud  tmed  prec  tmin  tmax  \
# 3377069 2011-10-29              PONTEVEDRA      645  10.0   0.0   2.2  17.8
# 2870280 2009-11-24               BARCELONA       56  14.8   0.0   9.9  19.7
# 4160846 2014-07-28                  BURGOS      771  19.8   0.0  14.2  25.5
# 2050656 2004-06-24                GIPUZKOA      460  18.1   1.0  11.7  24.5
# 365633  1978-07-14  SANTA CRUZ DE TENERIFE      310  18.8   0.0  13.5  24.0
# 3066923 2010-08-31                  MADRID      667  25.0   0.0  18.7  31.2
# 4873700 2016-11-29           ILLES BALEARS        3  15.4   0.0  10.6  20.3
# 1491190 1998-03-13               TARRAGONA       32  11.9   0.0   7.2  16.6
# 4635247 2016-02-19                LA RIOJA     1630  -3.0   1.0  -8.2   2.3
# 1506290 1998-05-22              LAS PALMAS        6  18.9   0.0  16.8  21.0
# 2180363 2005-07-21                A CORUÑA       98  22.4   0.0  16.8  28.1
# ...

# %%
corr = df.drop(columns = ['provincia']).corr()

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(corr,
            cmap="coolwarm",
            annot=True,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            fmt=".2f")
plt.show()

# %%
### Parte experimental###

# %%
variables_dependientes = [
                            'tmax',
                            'tmed',
                            'tmin',
                            'prec',
                            'racha'
                        ]

# %%
df_prov = (
    df.groupby(['fecha','provincia'])
      .agg({
          'tmax':'mean',
          'tmed':'mean',
          'tmin':'mean',
          'prec':'sum',      # Sumamos precipitación
          'racha':'max',     # Cogemos la racha máxima
      })
      .reset_index()
)

# %%
df_prov
# Out:
#                             tmax      tmed      tmin   prec  racha
# fecha      provincia
# 1970-01-01 A CORUÑA          8.5      4.75       1.0    0.0    7.5
#            ALBACETE          6.0       3.5       1.0    0.0   <NA>
#            ALICANTE        14.05      9.15      4.25    0.0   13.1
#            ALMERIA          14.4      10.4       6.4    5.5   <NA>
#            ARABA/ALAVA       3.6       1.5      -0.6    2.2   <NA>
# ...                          ...       ...       ...    ...    ...
# 2024-12-31 TOLEDO         10.825    3.8375    -3.175    0.2    6.4
#            VALENCIA        11.93     8.025     4.105  227.9    8.1
#            VALLADOLID      0.275      -0.9    -2.125    0.6    5.3
#            ZAMORA       0.561538 -0.746154 -2.046154    0.2    7.8
#            ZARAGOZA     3.769231  1.053846 -1.630769    0.0    5.3
#
# [1033798 rows x 5 columns]

# %%
display(df_prov.set_index('fecha').groupby('provincia').apply(lambda g: g.asfreq('D').interpolate()).reset_index(level = 0))
# Out:
#            provincia       tmax      tmed      tmin  prec  racha
# fecha
# 1970-01-01  A CORUÑA        8.5      4.75       1.0   0.0    7.5
# 1970-01-02  A CORUÑA        6.6      3.85       1.1   0.0   10.0
# 1970-01-03  A CORUÑA       10.0       6.6       3.2  56.0   13.1
# 1970-01-04  A CORUÑA      14.85      11.5       8.2  59.5   20.0
# 1970-01-05  A CORUÑA       11.4      8.75       6.1  51.0   15.6
# ...              ...        ...       ...       ...   ...    ...
# 2024-12-27  ZARAGOZA  12.176923  7.176923       2.2   0.4    7.8
# 2024-12-28  ZARAGOZA   7.138462  3.315385 -0.476923   0.6    8.1
# 2024-12-29  ZARAGOZA   5.192308  1.876923 -1.430769   0.2    5.3
# 2024-12-30  ZARAGOZA   4.223077  1.423077 -1.384615   0.0    5.3
# 2024-12-31  ZARAGOZA   3.769231  1.053846 -1.630769   0.0    5.3
#
# [1043685 rows x 6 columns]

# %%
df_prov = (
    df_prov.set_index('fecha')
           .groupby('provincia')
           .apply(lambda g: g.asfreq('D').interpolate()) # Forzamos a que haya una fila por día para cada subgrupo (g.asfreq('D')) e interpolamos
           .reset_index(level = 0)
)

# %%
scaler = StandardScaler()
df_scaled = df_prov.copy()
df_scaled[variables_dependientes] = scaler.fit_transform(
    df_scaled[variables_dependientes]
)

# %%
df_scaled.columns
# Out:
# Index(['provincia', 'tmax', 'tmed', 'tmin', 'prec', 'racha'], dtype='object')

# %%
provincia = "VALENCIA"
df_t = df_prov[df_prov['provincia'] == provincia]#.set_index('fecha')
df_t = df_t[variables_dependientes]

# Asegúrate de que no hay nulos
df_t = df_t.interpolate()

df_t = df_t.astype('float64')

# Split train / test
cutoff = '2022-12-31'
train = df_t.loc[:cutoff]
test = df_t.loc[cutoff:]

# Ajuste del modelo VARMAX
model = VARMAX(train, order=(2,1), trend='c')  # p=2, q=1
res = model.fit(disp=False)

print(res.summary())

# Predicción sobre el conjunto de test
pred = res.get_prediction(start=test.index[0], end=test.index[-1])
pred_mean = pred.predicted_mean

# Forecast a futuro
forecast_steps = 365*5  # 5 años
fc = res.get_forecast(steps=forecast_steps)
fc_mean = fc.predicted_mean

print(fc_mean.head())
# Out:
# C:\Users\Big Data\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\varmax.py:160: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# C:\Users\Big Data\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                        Statespace Model Results
# ...
# Dep. Variable:     ['tmax', 'tmed', 'tmin', 'prec', 'racha']   No. Observations:                19358
# Model:                                            VARMA(2,1)   Log Likelihood             -161384.924
#                                                  + intercept   AIC                         322959.848
# ...

# %%
for col in test.columns:
    mse = mean_squared_error(test[col], pred_mean[col])
    rmse = np.sqrt(mse)
    print(f"{col}: RMSE = {rmse:.2f}")
# Out:
# tmax: RMSE = 8.87
# tmed: RMSE = 7.65
# tmin: RMSE = 6.85
# prec: RMSE = 48.10
# racha: RMSE = 4.19
