# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.statespace.varmax import VARMAX

from sklearn.metrics import mean_squared_error, mean_absolute_error

from loader import cargar_dataset_limpio

# %%
df = cargar_dataset_limpio()

# %%
display(df.sample(20))
# Out:
#              fecha indicativo                                      nombre  \
# 597382  1983-07-13      C625O  SAN BARTOLOME TIRAJANA, LOMO PEDRO ALFONSO
# 4622305 2016-02-03      8486X                                 MOSQUERUELA
# 3937546 2013-10-24      4339X                                    CAÑAMERO
# 2826932 2009-09-22      7158X                                     ARCHENA
# 4148946 2014-07-13      3044X                                   CAÑIZARES
# 269976  1976-06-29       8175                         ALBACETE BASE AÉREA
# 1361439 1996-06-24      C629Q                          MOGÁN, PUERTO RICO
# 1614391 1999-10-03       B278               PALMA DE MALLORCA, AEROPUERTO
# 4574716 2015-12-08      9178X                             CAMPEZO/KANPEZU
# 2946012 2010-03-14      2624C                                       RIAÑO
# 2749948 2009-05-29      1060X                                     AMURRIO
# 6421161 2021-11-15       8376                                   JABALOYAS
# ...

# %%
columns_to_drop = [
    'indicativo',
    'nombre',
    # 'provincia',
    'horaPresMax',
    'horaPresMin',
    'horatmin',
    'horatmax',
    'horaracha',
    'horaHrMax',
    'horaHrMin',
    'dir_tipo'
]
df = df.drop(columns = columns_to_drop)

# %%
df['dir'] = df['dir'].replace([99, 88], np.nan)

# %%
display(df.sample(50))
# Out:
#              fecha               provincia  altitud  tmed  prec  tmin  tmax  \
# 1217040 1994-06-13                  TOLEDO      690  19.5   0.0  10.0  29.0
# 2215157 2005-10-26                  HUESCA      860  11.0   0.0   3.0  19.0
# 5116605 2017-09-12                 BADAJOZ      274  24.3   0.0  15.7  32.9
# 4016340 2014-01-31                ASTURIAS       30  12.3   7.6   9.1  15.5
# 6748169 2022-11-25                 CORDOBA      465  11.4   0.0   4.8  17.9
# 6080256 2020-10-17  SANTA CRUZ DE TENERIFE      310  21.0   0.0  17.2  24.9
# 3428835 2012-01-06                GIPUZKOA      290   9.6  <NA>   7.8  11.5
# 7155021 2024-03-02                  MURCIA      157  11.0   0.8   0.8  21.3
# 6130626 2020-12-14                ZARAGOZA      703  10.0   0.0   6.5  13.6
# 6294121 2021-06-21                  MURCIA      690  23.2   0.0  15.5  30.8
# 7079291 2023-12-07              VALLADOLID      734   5.0  13.4   0.9   9.2
# ...

# %%
corr = df.drop(columns = ['provincia']).corr()

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(corr,
            cmap="coolwarm",
            annot=True,
            xticklabels=corr.columns,
            yticklabels=corr.columns,
            fmt=".2f")
plt.show()

# %%
### Parte experimental###

# %%
df_prov = (
    df.groupby(['fecha','provincia'])
      .agg({
          'tmax':'mean',
          'tmed':'mean',
          'tmin':'mean',
          'prec':'sum',      # precipitación se suele sumar
          'racha':'max',     # racha máxima → valor máximo
      })
      .reset_index()
)

# %%
df_prov = (
    df_prov.set_index('fecha')
           .groupby('provincia')
           .apply(lambda g: g.asfreq('D').interpolate())
           .reset_index(level=0)
)

# %%
scaler = StandardScaler()
df_scaled = df_prov.copy()
df_scaled[['tmax','tmed','tmin','prec','racha']] = scaler.fit_transform(
    df_scaled[['tmax','tmed','tmin','prec','racha']]
)

# %%
df_scaled.columns
# Out:
# Index(['provincia', 'tmax', 'tmed', 'tmin', 'prec', 'racha'], dtype='object')

# %%
provincia = "TOLEDO"
df_t = df_prov[df_prov['provincia'] == provincia]#.set_index('fecha')
df_t = df_t[['tmax','tmed','tmin','prec','racha']]

# Asegúrate de que no hay nulos
df_t = df_t.interpolate()

df_t = df_t.astype('float64')


# Split train / test
cutoff = '2022-12-31'
train = df_t.loc[:cutoff]
test = df_t.loc[cutoff:]

# Ajuste del modelo VARMAX
model = VARMAX(train, order=(2,1), trend='c')  # p=2, q=1
res = model.fit(disp=False)

print(res.summary())

# Predicción sobre el conjunto de test
pred = res.get_prediction(start=test.index[0], end=test.index[-1])
pred_mean = pred.predicted_mean

# Forecast a futuro
forecast_steps = 365*5  # 5 años
fc = res.get_forecast(steps=forecast_steps)
fc_mean = fc.predicted_mean

print(fc_mean.head())
# Out:
# C:\Users\Big Data\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\varmax.py:160: EstimationWarning: Estimation of VARMA(p,q) models is not generically robust, due especially to identification issues.
#   warn('Estimation of VARMA(p,q) models is not generically robust,'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 14
#      11 test = df_t.loc[cutoff:]
#      13 # Ajuste del modelo VARMAX
# ---> 14 model = VARMAX(train, order=(2,1), trend='c')  # p=2, q=1
#      15 res = model.fit(disp=False)
#      17 print(res.summary())
#
# File ~\AppData\Roaming\Python\Python312\site-packages\statsmodels\tsa\statespace\varmax.py:199, in VARMAX.__init__(self, endog, exog, order, trend, error_cov_type, measurement_error, enforce_stationarity, enforce_invertibility, trend_offset, **kwargs)
# ...

# %%
df_t.dtypes
# Out:
# tmax     Float64
# tmed     Float64
# tmin     Float64
# prec     Float64
# racha    Float64
# dtype: object

# %%
for col in ['tmax','tmed','tmin','prec','racha']:
    print(f"Valores únicos en {col} que no son numéricos:")
    print(df_t[~df_t[col].apply(lambda x: isinstance(x, (int, float)))][col].unique())
# Out:
# Valores únicos en tmax que no son numéricos:
# <FloatingArray>
# []
# Length: 0, dtype: Float64
# Valores únicos en tmed que no son numéricos:
# <FloatingArray>
# []
# Length: 0, dtype: Float64
# Valores únicos en tmin que no son numéricos:
# <FloatingArray>
# []
# Length: 0, dtype: Float64
# Valores únicos en prec que no son numéricos:
# <FloatingArray>
# []
# Length: 0, dtype: Float64
# Valores únicos en racha que no son numéricos:
# <FloatingArray>
# []
# Length: 0, dtype: Float64

# %%
df_t.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2024-12-22', '2024-12-23', '2024-12-24', '2024-12-25',
#                '2024-12-26', '2024-12-27', '2024-12-28', '2024-12-29',
#                '2024-12-30', '2024-12-31'],
#               dtype='datetime64[ns]', name='fecha', length=20089, freq=None)
