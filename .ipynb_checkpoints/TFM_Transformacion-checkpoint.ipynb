# %%
import pandas as pd
import numpy as np

from loader import cargar_dataset_limpio

# %% [markdown]
# ### Carga del Dataset

# %%
df = cargar_dataset_limpio()

# %%
display(df)
# Out:
#                        fecha indicativo                    nombre   provincia  \
# 0        1970-01-01 00:00:00      C249I  FUERTEVENTURA AEROPUERTO  LAS PALMAS
# 1        1970-01-01 00:00:00      1679A         MONFORTE DE LEMOS        LUGO
# 2        1970-01-01 00:00:00       2462     PUERTO DE NAVACERRADA      MADRID
# 3        1970-01-01 00:00:00      1212E       ASTURIAS AEROPUERTO    ASTURIAS
# 4        1970-01-01 00:00:00      0016A           REUS AEROPUERTO   TARRAGONA
# ...                      ...        ...                       ...         ...
# 7424496  2024-12-31 00:00:00      9562X                   MORELLA   CASTELLON
# 7424497  2024-12-31 00:00:00      1002Y           BAZTAN, IRURITA     NAVARRA
# 7424498  2024-12-31 00:00:00      3254Y                      MORA      TOLEDO
# 7424499  2024-12-31 00:00:00      0194D   CORBERA, PUIG D'AGULLES   BARCELONA
# 7424500  2024-12-31 00:00:00      4093Y            OSA DE LA VEGA      CUENCA
#
#          altitud  tmed  prec  tmin  tmax  velmedia  ...   dir  racha  \
# 0             25  19.8   0.0  16.0  23.5       6.7  ...  <NA>   <NA>
# 1            291   4.0   0.0   0.0   8.0      <NA>  ...  <NA>   <NA>
# 2           1893  -5.0   0.4  -7.0  -3.0       3.1  ...  <NA>   <NA>
# 3            127   4.3   2.6   2.0   6.6       0.0  ...  99.0    7.2
# 4             71   5.5   0.0   0.6  10.4       1.7  ...  <NA>   <NA>
# ...          ...   ...   ...   ...   ...       ...  ...   ...    ...
# 7424496      990   4.8   0.0   0.8   8.8       1.4  ...  12.0    5.0
# 7424497      183   4.2   0.0  -4.9  13.4       0.0  ...  22.0    3.1
# 7424498      717   2.0   0.0  -3.1   7.1       1.1  ...  20.0    3.9
# 7424499      647  <NA>   0.0  <NA>  <NA>      <NA>  ...  <NA>   <NA>
# 7424500      763   4.1   0.0  -1.8  10.0       1.4  ...  99.0    6.1
#
#         horaracha  hrMax horaHrMax  hrMin horaHrMin        lon        lat  \
# 0             NaN   <NA>       NaN   <NA>       NaN -13.863056  28.444722
# 1             NaN   <NA>       NaN   <NA>       NaN  -7.510833  42.531667
# 2             NaN   <NA>       NaN   <NA>       NaN  -4.010556  40.793056
# 3           00:13   <NA>       NaN   <NA>       NaN  -6.044167  43.566944
# 4             NaN   <NA>       NaN   <NA>       NaN   1.163611     41.145
# ...           ...    ...       ...    ...       ...        ...        ...
# 7424496     16:50   97.0     23:50   63.0     14:00  -0.101944  40.621667
# 7424497     16:20  100.0     09:00   50.0     14:10  -1.543056  43.135833
# 7424498     14:30  100.0     09:20   80.0     11:20  -3.780556  39.686944
# 7424499       NaN   <NA>       NaN   <NA>       NaN      1.885  41.408056
# 7424500    Varias   97.0     09:00   62.0     15:50      -2.76  39.656111
#
#          dir_tipo
# 0          Válida
# 1          Válida
# 2          Válida
# 3          Varias
# 4          Válida
# ...           ...
# 7424496    Válida
# 7424497    Válida
# 7424498    Válida
# 7424499    Válida
# 7424500    Varias
#
# [7424501 rows x 28 columns]

# %%
df_prep = df.copy(deep = True)

# %% [markdown]
# ### Reestructuración en formato tidy data

# %%
COL_FECHA = 'fecha'

COLS_HORAS = [
    'horaPresMax',
    'horaPresMin',
    'horatmin',
    'horatmax',
    'horaracha',
    'horaHrMax',
    'horaHrMin'
]

SUFIJO_TIPO = '_tipo'

VAL_VARIAS = 'Varias'

CATEGORIAS = ['Desconocida',
              VAL_VARIAS,
              'Válida',
              'Inválida'] # Valor por defecto si no cuadra en ninguna de las demás

# %%
# Procesamiento de horas
for col in COLS_HORAS:

    filtro_formato = df_prep[col].str.match(r'^\d{1,2}:\d{2}$', na=False) # Comprueba que formato HH:MM
    df_hhmm = df_prep.loc[filtro_formato, col].str.split(":", expand=True).astype(int) # Df con dos columnas: HH y MM
    filtro_rango = (df_hhmm[0].between(0, 23)) & (df_hhmm[1].between(0, 59)) # Comprueba HH entre 0-23; MM entre 0-59 
    filtro_hhmm = filtro_rango.reindex(df_prep.index, fill_value = False) # Para mismo tamaño que original
    
    # Anotamos anomalías en la hora
    filtros = [                       # Esta lista se corresponde con la de CATEGORIAS
        df_prep[col].isna(),          # No hay valor -> Desconocida
        df_prep[col] == VAL_VARIAS,   # Varias -> Varias
        filtro_hhmm                   # Todo correcto -> Válida
    ]                                 # Cualquier otro caso -> Inválida

    df_prep[col + SUFIJO_TIPO] = np.select(filtros, CATEGORIAS[:-1], default = CATEGORIAS[-1])
    df_prep[col + SUFIJO_TIPO] = df_prep[col + SUFIJO_TIPO].astype('category')

    # Pasamos las horas a tipo time
    df_prep[col] = pd.to_datetime(
        df_prep[col], format = '%H:%M', errors = 'coerce'
    ).dt.time

    # Creamos columna datetime respectiva
    df_prep[COL_FECHA + col] = pd.to_datetime(
        df_prep[COL_FECHA].dt.date.astype(str) + ' ' + df_prep[col].astype(str),
        format = '%Y-%m-%d %H:%M',
        errors = 'coerce'
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 31
#      25 df_prep[col] = pd.to_datetime(
#      26     df_prep[col], format = '%H:%M', errors = 'coerce'
#      27 ).dt.time
#      29 # Creamos columna datetime respectiva
#      30 df_prep['fecha' + col] = pd.to_datetime(
# ---> 31     df_prep[COL_FECHA].dt.date.astype(str) + ' ' + df_prep[col].astype(str),
#      32     format = '%Y-%m-%d %H:%M',
#      33     errors = 'coerce'
#      34 )
#
# NameError: name 'COL_FECHA' is not defined

# %%
df_prep.to_csv('Valores_Climatologicos_1970_2024_Tipos_Horas.csv', sep = ';', index = False)
