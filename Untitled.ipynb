# %%
import pandas as pd

# %%
url = 'Valores_Climatologicos_1970_2024_Tidy_Lite.csv'
df = pd.read_csv(url, sep=';', nrows = 0)

# %%
df.columns
# Out:
# Index(['fecha', 'nombre', 'provincia', 'variable', 'valor'], dtype='object')
